# %% [markdown]
# # Detecção de Fraudes - Treinamento com colunas corretas

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from models.fraud_detection_model import train_fraud_model_from_file

# Visualizar correlação
df = pd.read_csv('../data/transactions.csv')
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# Treinar e salvar modelo
model = train_fraud_model_from_file('../data/transactions.csv')
# Out:
# Epoch 1/10
# c:\Users\guilh\miniconda3\envs\Projeto_ML\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8529 - loss: 0.6640 - val_accuracy: 0.9550 - val_loss: 0.5227
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9546 - loss: 0.4316 - val_accuracy: 0.9550 - val_loss: 0.1846
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9515 - loss: 0.2047 - val_accuracy: 0.9550 - val_loss: 0.1895
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9546 - loss: 0.1879 - val_accuracy: 0.9550 - val_loss: 0.1827
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9519 - loss: 0.1910 - val_accuracy: 0.9550 - val_loss: 0.1857
# Epoch 6/10
# ...
