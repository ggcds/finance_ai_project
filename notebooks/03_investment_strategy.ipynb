# %% [markdown]
# # Estratégia de Investimentos - Treinamento e salvamento

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from models.investment_optimizer import train_investment_model_from_file

# Visualizar os dados
df = pd.read_csv('../data/market_data.csv')
sns.pairplot(df)
plt.show()

# Treinar e salvar modelo
model = train_investment_model_from_file('../data/market_data.csv')
# Out:
# Epoch 1/20
# c:\Users\guilh\miniconda3\envs\Projeto_ML\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8942e-04 - val_loss: 0.0012
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8278e-04 - val_loss: 0.0012
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2409e-04 - val_loss: 0.0011
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6721e-04 - val_loss: 0.0012
# Epoch 8/20
# ...
